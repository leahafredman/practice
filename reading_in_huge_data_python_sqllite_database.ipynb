# %%
#importing libraries
import pandas as pd
from dfply import *
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import os
# %matplotlib inline

# %%
#csv_database.dispose()
#os.remove('csv_database.db')

# %%
#setting display options for pandas
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
#coding ideas and comments from https://stackoverflow.com/questions/42900757/sequentially-read-huge-csv-file-in-python/42960918
#trying to understand what would be the best way to handle these data if they were huge
file = '/Users/ariafredman/Documents/data_science/data/star_wars_info_data/characters.csv'
#checking out the first 5 rows of the data
#not necessary for these small data
#but could be good if our data are super large
print(pd.read_csv(file, nrows = 5))
# Out:
#              name  height  mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker     172    77      blond         fair      blue      19BBY
# 1           C-3PO     167    75        NaN         gold    yellow     112BBY
# 2           R2-D2      96    32        NaN  white, blue       red      33BBY
# 3     Darth Vader     202   136       none        white    yellow    41.9BBY
# 4     Leia Organa     150    49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
#creating the sqllite database
csv_database = create_engine('sqlite:///csv_database.db')

# %%
#iterating through the CSV file in chunks and store the data into sqllite
#setting the chunksize at 10 which means we'll have 10 rows per chunk
#The for loop read a chunk of data from the CSV file, 
#If you want to remove space from any of column names
#use df = df.rename(columns={c: c.replace(' ', '') for c in df.columns}) 
#then stores the chunk into the sqllite database (df.to_sql(…))
chunksize = 10
index_offset = 1
for df in pd.read_csv(file, chunksize = chunksize, iterator = True):
      df.index += index_offset
      df.to_sql('table', csv_database, if_exists = 'append')
      index_offset += 1

# %%
#we can now pull the data from the query
df1 = pd.read_sql_query("SELECT * FROM 'table' LIMIT 5", csv_database)
print(df1)
# Out:
#    index            name  height  mass hair_color   skin_color eye_color  \
# 0      1  Luke Skywalker     172    77      blond         fair      blue
# 1      2           C-3PO     167    75       None         gold    yellow
# 2      3           R2-D2      96    32       None  white, blue       red
# 3      4     Darth Vader     202   136       none        white    yellow
# 4      5     Leia Organa     150    49      brown        light     brown
#
#   birth_year  gender homeworld species
# 0      19BBY    male  Tatooine   Human
# 1     112BBY    None  Tatooine   Droid
# 2      33BBY    None     Naboo   Droid
# 3    41.9BBY    male  Tatooine   Human
# 4      19BBY  female  Alderaan   Human

# %%
df_char_sql = pd.read_sql_query("SELECT * FROM 'table'", csv_database)

# %%
#another option if you can pull it all into memory
#but maybe the reading in part is the problematic one
#this data output isn't dataframe, but pandas.io.parsers.TextFileReader
it_df_char = pd.read_csv(file, iterator = True, chunksize=10)
print(it_df_char)
# Out:
# <pandas.io.parsers.TextFileReader object at 0x7fdb19b6a510>

# %%
#If you need a dataframe use concat for all chunks to df
chunks_list = []

for chunk in pd.read_csv(file, iterator = True, chunksize = 10):
    chunks_list.append(chunk)
    
#we can use this to see how many chunks we have:
print("Number of chunks: ", len(l1))

df_char_it = pd.concat(l1, ignore_index = True)

print(df_char_it.head(9))
print(df_char_it.shape)
# Out:
# Number of chunks:  9
#                  name  height mass   hair_color   skin_color eye_color  \
# 0      Luke Skywalker   172.0   77        blond         fair      blue
# 1               C-3PO   167.0   75          NaN         gold    yellow
# 2               R2-D2    96.0   32          NaN  white, blue       red
# 3         Darth Vader   202.0  136         none        white    yellow
# 4         Leia Organa   150.0   49        brown        light     brown
# 5           Owen Lars   178.0  120  brown, grey        light      blue
# 6  Beru Whitesun lars   165.0   75        brown        light      blue
# 7               R5-D4    97.0   32          NaN   white, red       red
# 8   Biggs Darklighter   183.0   84        black        light     brown
#
#   birth_year  gender homeworld species
# 0      19BBY    male  Tatooine   Human
# 1     112BBY     NaN  Tatooine   Droid
# 2      33BBY     NaN     Naboo   Droid
# 3    41.9BBY    male  Tatooine   Human
# 4      19BBY  female  Alderaan   Human
# 5      52BBY    male  Tatooine   Human
# 6      47BBY  female  Tatooine   Human
# 7        NaN     NaN  Tatooine   Droid
# 8      24BBY    male  Tatooine   Human
# (87, 10)

# %%
#reading the data in the usual way
df_char_usual = pd.read_csv('/Users/ariafredman/Documents/data_science/data/star_wars_info_data/characters.csv')
df_char_usual.head(9)
# Out:
#                  name  height mass   hair_color   skin_color eye_color  \
# 0      Luke Skywalker   172.0   77        blond         fair      blue
# 1               C-3PO   167.0   75          NaN         gold    yellow
# 2               R2-D2    96.0   32          NaN  white, blue       red
# 3         Darth Vader   202.0  136         none        white    yellow
# 4         Leia Organa   150.0   49        brown        light     brown
# 5           Owen Lars   178.0  120  brown, grey        light      blue
# 6  Beru Whitesun lars   165.0   75        brown        light      blue
# 7               R5-D4    97.0   32          NaN   white, red       red
# 8   Biggs Darklighter   183.0   84        black        light     brown
#
#   birth_year  gender homeworld species
# 0      19BBY    male  Tatooine   Human
# 1     112BBY     NaN  Tatooine   Droid
# 2      33BBY     NaN     Naboo   Droid
# 3    41.9BBY    male  Tatooine   Human
# 4      19BBY  female  Alderaan   Human
# 5      52BBY    male  Tatooine   Human
# 6      47BBY  female  Tatooine   Human
# 7        NaN     NaN  Tatooine   Droid
# 8      24BBY    male  Tatooine   Human

# %%
#Checking that all df_char_usual and df_char_it are the same
df_char_usual.equals(df_char_it)
#these aren't identical
# Out:
# False

# %%
#making them all objects doesn't seem to have fixed the issue
df_char_usualstr = df_char_usual.copy(deep = True).astype(str)
df_char_itstr = df_char_it.copy(deep = True).astype(str)
print('Are df_char_usualstr and df_char_itstr identical? \n', (df_char_usualstr).equals(df_char_itstr))
print('df_char_itstr data types: \n', df_char_itstr.dtypes)
print('df_char_usualstr data types: \n', df_char_usualstr.dtypes)
# Out:
# Are df_char_usualstr and df_char_itstr identical?
#  False
# df_char_itstr data types:
#  name          object
# height        object
# mass          object
# hair_color    object
# skin_color    object
# eye_color     object
# birth_year    object
# gender        object
# homeworld     object
# species       object
# dtype: object
# df_char_usualstr data types:
#  name          object
# height        object
# mass          object
# hair_color    object
# skin_color    object
# eye_color     object
# birth_year    object
# gender        object
# homeworld     object
# species       object
# dtype: object

# %%
#creating an array to see where does each value matchs and misses
comparison_array = df_char_usual.values == df_char_it.values
#first 5 rows
print(comparison_array[0:5])
# Out:
# [[ True  True False  True  True  True  True  True  True  True]
#  [ True  True False False  True  True  True False  True  True]
#  [ True  True False False  True  True  True False  True  True]
#  [ True  True False  True  True  True  True  True  True  True]
#  [ True  True False  True  True  True  True  True  True  True]]

# %%
#these are the cells that are supposed to be problematic in the 1st row
print(df_char_usual.iloc[0,2])
print(df_char_it.iloc[0,2])
#python thinks these are different
print(df_char_usual.iloc[0,2] == df_char_it.iloc[0,2])
print(str(df_char_usual.iloc[0,2]) == str(df_char_it.iloc[0,2]))
#I think this proves that the data are equivalent, 
#but something about converting the entire dataframe and/or how pandas is evaluating things is messed up
# Out:
# 77
# 77
# False
# True

# %%
#so these also aren't identical
#so let's look into that a bit more
print(df_char_usual.equals(df_char_sql))
print(df_char_it.equals(df_char_sql))
# Out:
# False
# False

# %%
print(df_char_sql.head())
#it looks like it may just be the extra index column
# Out:
#    index            name  height mass hair_color   skin_color eye_color  \
# 0      1  Luke Skywalker   172.0   77      blond         fair      blue
# 1      2           C-3PO   167.0   75       None         gold    yellow
# 2      3           R2-D2    96.0   32       None  white, blue       red
# 3      4     Darth Vader   202.0  136       none        white    yellow
# 4      5     Leia Organa   150.0   49      brown        light     brown
#
#   birth_year  gender homeworld species
# 0      19BBY    male  Tatooine   Human
# 1     112BBY    None  Tatooine   Droid
# 2      33BBY    None     Naboo   Droid
# 3    41.9BBY    male  Tatooine   Human
# 4      19BBY  female  Alderaan   Human

# %%
df_char_sql = df_char_sql >> drop(['index'])

# %%
df_char_sql.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75       None         gold    yellow     112BBY
# 2           R2-D2    96.0   32       None  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1    None  Tatooine   Droid
# 2    None     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
#crap still not equal
print(df_char_usual.equals(df_char_sql))
print(df_char_it.equals(df_char_sql))
#maybe the datatypes?
# Out:
# False
# False

# %%
df_char_usual.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
#no, that's not it either
print(df_char_usual.dtypes)
print(df_char_sql.dtypes)
# Out:
# name           object
# height        float64
# mass           object
# hair_color     object
# skin_color     object
# eye_color      object
# birth_year     object
# gender         object
# homeworld      object
# species        object
# dtype: object
# name           object
# height        float64
# mass           object
# hair_color     object
# skin_color     object
# eye_color      object
# birth_year     object
# gender         object
# homeworld      object
# species        object
# dtype: object

# %%
#well that's not the same
#it looks like maybe the sql one had a duplicate row for each?
print('The shape of the data imported the usual way is :', df_char_usual.shape)
print('The shape of the data imported the database way is :',df_char_sql.shape)
# Out:
# The shape of the data imported the usual way is : (87, 10)
# The shape of the data imported the database way is : (87, 10)

# %%
#I think it would be helpful to close and dispose of the engine and then try again
#because I ran the code a few times so I think it kept re-appending
csv_database.dispose()
os.remove('csv_database.db')

# %%
#the above seems to have 
#closed and dispoed of the engine
print(pd.read_sql_query("SELECT * FROM 'table'", csv_database))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# OperationalError: no such table: table
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-96-f5f3675bd05c> in <module>
#       1 #the above seems to have
#       2 #closed and dispoed of the engine
# ----> 3 print(pd.read_sql_query("SELECT * FROM 'table'", csv_database))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2180
#    2181         connection = self._contextual_connect(close_with_result=True)
# -> 2182         return connection.execute(statement, *multiparams, **params)
#    2183
#    2184     def scalar(self, statement, *multiparams, **params):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     974         """
#     975         if isinstance(object_, util.string_types[0]):
# --> 976             return self._execute_text(object_, multiparams, params)
#     977         try:
#     978             meth = object_._execute_on_connection
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1147             parameters,
#    1148             statement,
# -> 1149             parameters,
#    1150         )
#    1151         if self._has_events or self.engine._has_events:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1244                 if not evt_handled:
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#    1248         except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     586
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#     590     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: table
# [SQL: SELECT * FROM 'table']
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
#rebuilding the engine and redoing everything
#and then checking if everything is equal
csv_database = create_engine('sqlite:///csv_database.db')

chunksize = 10
index_offset = 1
for df in pd.read_csv(file, chunksize = chunksize, iterator = True):
      df.index += index_offset
      df.to_sql('table', csv_database, if_exists = 'append')
      index_offset += 1

# %%
df_char_sql1 = pd.read_sql_query("SELECT * FROM 'table'", csv_database)

df_char_sql1 = df_char_sql1 >> drop(['index'])

print(df_char_usual.equals(df_char_sql1))
print(df_char_it.equals(df_char_sql1))
#YAYAYAYAY
# Out:
# False
# False

# %%
df_char_sql1.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75       None         gold    yellow     112BBY
# 2           R2-D2    96.0   32       None  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1    None  Tatooine   Droid
# 2    None     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
#dumping the database and rebuilding without the index_offset, and then checking that dataframes are equal
#this looks the same but it's not
#and tbh I'm too lazy to look for the differences right now
csv_database.dispose()
os.remove('csv_database.db')

csv_database = create_engine('sqlite:///csv_database.db')

chunksize = 10

for df in pd.read_csv(file, chunksize = chunksize, iterator = True):
      df.to_sql('table', csv_database, if_exists = 'append')

df_char_sql2 = pd.read_sql_query("SELECT * FROM 'table'", csv_database)

df_char_sql2 = df_char_sql2 >> drop(['index'])

print(df_char_usual.equals(df_char_sql2))
print(df_char_it.equals(df_char_sql2))
print(df_char_sql1.equals(df_char_sql2))
# Out:
# False
# False
# True

# %%
#looking at the unshared columns
df_char_sql1.merge(df_char_sql2, how = 'outer' ,indicator=False)
# Out:
#                      name  height   mass     hair_color           skin_color  \
# 0          Luke Skywalker   172.0     77          blond                 fair
# 1                   C-3PO   167.0     75           None                 gold
# 2                   R2-D2    96.0     32           None          white, blue
# 3             Darth Vader   202.0    136           none                white
# 4             Leia Organa   150.0     49          brown                light
# 5               Owen Lars   178.0    120    brown, grey                light
# 6      Beru Whitesun lars   165.0     75          brown                light
# 7                   R5-D4    97.0     32           None           white, red
# 8       Biggs Darklighter   183.0     84          black                light
# 9          Obi-Wan Kenobi   182.0     77  auburn, white                 fair
# 10       Anakin Skywalker   188.0     84          blond                 fair
# 11         Wilhuff Tarkin   180.0   None   auburn, grey                 fair
# 12              Chewbacca   228.0    112          brown                 None
# 13               Han Solo   180.0     80          brown                 fair
# 14                 Greedo   173.0     74           None                green
# 15  Jabba Desilijic Tiure   175.0  1,358           None     green-tan, brown
# 16         Wedge Antilles   170.0     77          brown                 fair
# 17       Jek Tono Porkins   180.0    110          brown                 fair
# 18                   Yoda    66.0     17          white                green
# 19              Palpatine   170.0     75           grey                 pale
# 20              Boba Fett   183.0   78.2          black                 fair
# 21                  IG-88   200.0    140           none                metal
# 22                  Bossk   190.0    113           none                green
# 23       Lando Calrissian   177.0     79          black                 dark
# 24                  Lobot   175.0     79           none                light
# 25                 Ackbar   180.0     83           none         brown mottle
# 26             Mon Mothma   150.0   None         auburn                 fair
# 27           Arvel Crynyd     NaN   None          brown                 fair
# 28  Wicket Systri Warrick    88.0     20          brown                brown
# 29              Nien Nunb   160.0     68           none                 grey
# 30           Qui-Gon Jinn   193.0     89          brown                 fair
# 31            Nute Gunray   191.0     90           none        mottled green
# 32          Finis Valorum   170.0   None          blond                 fair
# 33          Jar Jar Binks   196.0     66           none               orange
# 34           Roos Tarpals   224.0     82           none                 grey
# 35             Rugor Nass   206.0   None           none                green
# 36               Ric Olié   183.0   None          brown                 fair
# 37                  Watto   137.0   None          black           blue, grey
# 38                Sebulba   112.0     40           none            grey, red
# 39          Quarsh Panaka   183.0   None          black                 dark
# 40         Shmi Skywalker   163.0   None          black                 fair
# 41             Darth Maul   175.0     80           none                  red
# 42            Bib Fortuna   180.0   None           none                 pale
# 43            Ayla Secura   178.0     55           none                 blue
# 44               Dud Bolt    94.0     45           none           blue, grey
# 45                Gasgano   122.0   None           none          white, blue
# 46         Ben Quadinaros   163.0     65           none  grey, green, yellow
# 47             Mace Windu   188.0     84           none                 dark
# 48           Ki-Adi-Mundi   198.0     82          white                 pale
# 49              Kit Fisto   196.0     87           none                green
# 50              Eeth Koth   171.0   None          black                brown
# 51             Adi Gallia   184.0     50           none                 dark
# 52            Saesee Tiin   188.0   None           none                 pale
# 53            Yarael Poof   264.0   None           none                white
# 54               Plo Koon   188.0     80           none               orange
# 55             Mas Amedda   196.0   None           none                 blue
# 56           Gregar Typho   185.0     85          black                 dark
# 57                  Cordé   157.0   None          brown                light
# 58            Cliegg Lars   183.0   None          brown                 fair
# 59      Poggle the Lesser   183.0     80           none                green
# 60        Luminara Unduli   170.0   56.2          black               yellow
# 61          Barriss Offee   166.0     50          black               yellow
# 62                  Dormé   165.0   None          brown                light
# 63                  Dooku   193.0     80          white                 fair
# 64    Bail Prestor Organa   191.0   None          black                  tan
# 65             Jango Fett   183.0     79          black                  tan
# 66             Zam Wesell   168.0     55         blonde  fair, green, yellow
# 67        Dexter Jettster   198.0    102           none                brown
# 68                Lama Su   229.0     88           none                 grey
# 69                Taun We   213.0   None           none                 grey
# 70             Jocasta Nu   167.0   None          white                 fair
# 71          Ratts Tyerell    79.0     15           none           grey, blue
# 72                 R4-P17    96.0   None           none          silver, red
# 73             Wat Tambor   193.0     48           none          green, grey
# 74               San Hill   191.0   None           none                 grey
# 75               Shaak Ti   178.0     57           none     red, blue, white
# 76               Grievous   216.0    159           none         brown, white
# 77                Tarfful   234.0    136          brown                brown
# 78        Raymus Antilles   188.0     79          brown                light
# 79              Sly Moore   178.0     48           none                 pale
# 80             Tion Medon   206.0     80           none                 grey
# 81                   Finn     NaN   None          black                 dark
# 82                    Rey     NaN   None          brown                light
# 83            Poe Dameron     NaN   None          brown                light
# 84                    BB8     NaN   None           none                 none
# 85         Captain Phasma     NaN   None           None                 None
# 86          Padmé Amidala   165.0     45          brown                light
#
#         eye_color birth_year         gender       homeworld         species
# 0            blue      19BBY           male        Tatooine           Human
# 1          yellow     112BBY           None        Tatooine           Droid
# 2             red      33BBY           None           Naboo           Droid
# 3          yellow    41.9BBY           male        Tatooine           Human
# 4           brown      19BBY         female        Alderaan           Human
# 5            blue      52BBY           male        Tatooine           Human
# 6            blue      47BBY         female        Tatooine           Human
# 7             red       None           None        Tatooine           Droid
# 8           brown      24BBY           male        Tatooine           Human
# 9       blue-gray      57BBY           male         Stewjon           Human
# 10           blue    41.9BBY           male        Tatooine           Human
# 11           blue      64BBY           male          Eriadu           Human
# 12           blue     200BBY           male        Kashyyyk         Wookiee
# 13          brown      29BBY           male        Corellia           Human
# 14          black      44BBY           male           Rodia          Rodian
# 15         orange     600BBY  hermaphrodite       Nal Hutta            Hutt
# 16          hazel      21BBY           male        Corellia           Human
# 17           blue       None           male      Bestine IV           Human
# 18          brown     896BBY           male            None  Yoda's species
# 19         yellow      82BBY           male           Naboo           Human
# 20          brown    31.5BBY           male          Kamino           Human
# 21            red      15BBY           none            None           Droid
# 22            red      53BBY           male       Trandosha      Trandoshan
# 23          brown      31BBY           male         Socorro           Human
# 24           blue      37BBY           male          Bespin           Human
# 25         orange      41BBY           male        Mon Cala    Mon Calamari
# 26           blue      48BBY         female       Chandrila           Human
# 27          brown       None           male            None           Human
# 28          brown       8BBY           male           Endor            Ewok
# 29          black       None           male         Sullust       Sullustan
# 30           blue      92BBY           male            None           Human
# 31            red       None           male  Cato Neimoidia       Neimodian
# 32           blue      91BBY           male       Coruscant           Human
# 33         orange      52BBY           male           Naboo          Gungan
# 34         orange       None           male           Naboo          Gungan
# 35         orange       None           male           Naboo          Gungan
# 36           blue       None           male           Naboo            None
# 37         yellow       None           male        Toydaria       Toydarian
# 38         orange       None           male       Malastare             Dug
# 39          brown      62BBY           male           Naboo            None
# 40          brown      72BBY         female        Tatooine           Human
# 41         yellow      54BBY           male        Dathomir          Zabrak
# 42           pink       None           male          Ryloth         Twi'lek
# 43          hazel      48BBY         female          Ryloth         Twi'lek
# 44         yellow       None           male         Vulpter      Vulptereen
# 45          black       None           male         Troiken           Xexto
# 46         orange       None           male            Tund           Toong
# 47          brown      72BBY           male      Haruun Kal           Human
# 48         yellow      92BBY           male           Cerea          Cerean
# 49          black       None           male     Glee Anselm        Nautolan
# 50          brown       None           male        Iridonia          Zabrak
# 51           blue       None         female       Coruscant      Tholothian
# 52         orange       None           male         Iktotch        Iktotchi
# 53         yellow       None           male         Quermia        Quermian
# 54          black      22BBY           male           Dorin         Kel Dor
# 55           blue       None           male        Champala        Chagrian
# 56          brown       None           male           Naboo           Human
# 57          brown       None         female           Naboo           Human
# 58           blue      82BBY           male        Tatooine           Human
# 59         yellow       None           male        Geonosis       Geonosian
# 60           blue      58BBY         female          Mirial        Mirialan
# 61           blue      40BBY         female          Mirial        Mirialan
# 62          brown       None         female           Naboo           Human
# 63          brown     102BBY           male         Serenno           Human
# 64          brown      67BBY           male        Alderaan           Human
# 65          brown      66BBY           male    Concord Dawn           Human
# 66         yellow       None         female           Zolan        Clawdite
# 67         yellow       None           male            Ojom        Besalisk
# 68          black       None           male          Kamino        Kaminoan
# 69          black       None         female          Kamino        Kaminoan
# 70           blue       None         female       Coruscant           Human
# 71           None       None           male     Aleen Minor          Aleena
# 72      red, blue       None         female            None            None
# 73           None       None           male           Skako         Skakoan
# 74           gold       None           male      Muunilinst            Muun
# 75          black       None         female           Shili         Togruta
# 76  green, yellow       None           male           Kalee         Kaleesh
# 77           blue       None           male        Kashyyyk         Wookiee
# 78          brown       None           male        Alderaan           Human
# 79          white       None         female          Umbara            None
# 80          black       None           male          Utapau          Pau'an
# 81           dark       None           male            None           Human
# 82          hazel       None         female            None           Human
# 83          brown       None           male            None           Human
# 84          black       None           none            None           Droid
# 85           None       None         female            None            None
# 86          brown      46BBY         female           Naboo           Human

# %%
df_char_sql1.replace(' ', 'LLLLLLL', regex=True)
#it doesn't seem to be whitespaces

# %%
df_char_sql2.replace(' ', 'LLLLLLL', regex=True)

# %%
print(df_char_sql2.shape)
print(df_char_sql1.shape)

# %%
print((df_char_sql2.replace(' ', 'LLLLLLL', regex=True)).equals((df_char_sql1.replace(' ', 'LLLLLLL', regex=True))))
