# %%
#importing libraries
import pandas as pd
from dfply import *
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import os
# %matplotlib inline

# %%
#setting display options for pandas
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
#coding ideas and comments from https://stackoverflow.com/questions/42900757/sequentially-read-huge-csv-file-in-python/42960918
#trying to understand what would be the best way to handle these data if they were huge
file = '/Users/ariafredman/Documents/data_science/data/star_wars_info_data/characters.csv'
#checking out the first 5 rows of the data
#not necessary for these small data
#but could be good if our data are super large
print(pd.read_csv(file, nrows = 5))
# Out:
#              name  height  mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker     172    77      blond         fair      blue      19BBY
# 1           C-3PO     167    75        NaN         gold    yellow     112BBY
# 2           R2-D2      96    32        NaN  white, blue       red      33BBY
# 3     Darth Vader     202   136       none        white    yellow    41.9BBY
# 4     Leia Organa     150    49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
#creating the sqllite database
csv_database = create_engine('sqlite:///csv_database.db')

# %%
#iterating through the CSV file in chunks and store the data into sqllite
#setting the chunksize at 100,000 to keep the size of the chunks managable
#The for loop read a chunk of data from the CSV file, 
#If you want to remove space from any of column names
#use df = df.rename(columns={c: c.replace(' ', '') for c in df.columns}) 
#then stores the chunk into the sqllite database (df.to_sql(…))
chunksize = 100000
index_offset = 1
for df in pd.read_csv(file, chunksize = chunksize, iterator = True):
      df.index += index_offset
      df.to_sql('table', csv_database, if_exists = 'append')
      index_offset += 1

# %%
#we can now pull the data from the query
df1 = pd.read_sql_query("SELECT * FROM 'table' LIMIT 5", csv_database)
print(df1)
# Out:
#    index            name  height mass hair_color   skin_color eye_color  \
# 0      1  Luke Skywalker   172.0   77      blond         fair      blue
# 1      2           C-3PO   167.0   75       None         gold    yellow
# 2      3           R2-D2    96.0   32       None  white, blue       red
# 3      4     Darth Vader   202.0  136       none        white    yellow
# 4      5     Leia Organa   150.0   49      brown        light     brown
#
#   birth_year  gender homeworld species
# 0      19BBY    male  Tatooine   Human
# 1     112BBY    None  Tatooine   Droid
# 2      33BBY    None     Naboo   Droid
# 3    41.9BBY    male  Tatooine   Human
# 4      19BBY  female  Alderaan   Human

# %%
df_char_sql = pd.read_sql_query("SELECT * FROM 'table'", csv_database)

# %%
#another option if you can pull it all into memory
#but maybe the reading in part is the problematic one
#this data output isn't dataframe, but pandas.io.parsers.TextFileReader
it_df_char = pd.read_csv('/Users/ariafredman/Documents/data_science/data/star_wars_info_data/characters.csv', iterator = True, chunksize=1000)
print(it_df_char)
# Out:
# <pandas.io.parsers.TextFileReader object at 0x7fbb985f1dd0>

# %%
#If you need a dataframe use concat for all chunks to df
df_char_it = pd.concat(it_df_char, ignore_index = True)
df_char_it.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
#reading the data in the usual way
df_char_usual = pd.read_csv('/Users/ariafredman/Documents/data_science/data/star_wars_info_data/characters.csv')

# %%
#Checking that all df_char_usual and df_char_it are the same
df_char_usual.equals(df_char_it)
# Out:
# True

# %%
#so these aren't identical
#so let's look into that a bit more
df_char_usual.equals(df_char_sql)
df_char_it.equals(df_char_sql)
# Out:
# False

# %%
print(df_char_sql.head())
#it looks like it may just be the extra index column
# Out:
#    index            name  height mass hair_color   skin_color eye_color  \
# 0      1  Luke Skywalker   172.0   77      blond         fair      blue
# 1      2           C-3PO   167.0   75       None         gold    yellow
# 2      3           R2-D2    96.0   32       None  white, blue       red
# 3      4     Darth Vader   202.0  136       none        white    yellow
# 4      5     Leia Organa   150.0   49      brown        light     brown
#
#   birth_year  gender homeworld species
# 0      19BBY    male  Tatooine   Human
# 1     112BBY    None  Tatooine   Droid
# 2      33BBY    None     Naboo   Droid
# 3    41.9BBY    male  Tatooine   Human
# 4      19BBY  female  Alderaan   Human

# %%
df_char_sql = df_char_sql >> drop(['index'])

# %%
df_char_sql.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75       None         gold    yellow     112BBY
# 2           R2-D2    96.0   32       None  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1    None  Tatooine   Droid
# 2    None     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
#crap still not equal
df_char_usual.equals(df_char_sql)
df_char_it.equals(df_char_sql)
#maybe the datatypes?
# Out:
# True

# %%
df_char_usual.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
#no, that's not it either
print(df_char_usual.dtypes)
print(df_char_sql.dtypes)
# Out:
# name           object
# height        float64
# mass           object
# hair_color     object
# skin_color     object
# eye_color      object
# birth_year     object
# gender         object
# homeworld      object
# species        object
# dtype: object
# name           object
# height        float64
# mass           object
# hair_color     object
# skin_color     object
# eye_color      object
# birth_year     object
# gender         object
# homeworld      object
# species        object
# dtype: object

# %%
#well that's not the same
#it looks like maybe the sql one had a duplicate row for each?
print('The shape of the data imported the usual way is :', df_char_usual.shape)
print('The shape of the data imported the database way is :',df_char_sql.shape)
# Out:
# The shape of the data imported the usual way is : (87, 10)
# The shape of the data imported the database way is : (87, 10)

# %%
#I think it would be helpful to close and dispose of the engine and then try again
#because I ran the code a few times so I think it kept re-appending
csv_database.dispose()
os.remove('csv_database.db')

# %%
#the above seems to have 
#closed and dispoed of the engine
print(pd.read_sql_query("SELECT * FROM 'table'", csv_database))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# OperationalError: no such table: table
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-21-f5f3675bd05c> in <module>
#       1 #the above seems to have
#       2 #closed and dispoed of the engine
# ----> 3 print(pd.read_sql_query("SELECT * FROM 'table'", csv_database))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2180
#    2181         connection = self._contextual_connect(close_with_result=True)
# -> 2182         return connection.execute(statement, *multiparams, **params)
#    2183
#    2184     def scalar(self, statement, *multiparams, **params):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     974         """
#     975         if isinstance(object_, util.string_types[0]):
# --> 976             return self._execute_text(object_, multiparams, params)
#     977         try:
#     978             meth = object_._execute_on_connection
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1147             parameters,
#    1148             statement,
# -> 1149             parameters,
#    1150         )
#    1151         if self._has_events or self.engine._has_events:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1244                 if not evt_handled:
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#    1248         except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     586
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#     590     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: table
# [SQL: SELECT * FROM 'table']
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
#rebuilding the engine and redoing everything
#and then checking if everything is equal
csv_database = create_engine('sqlite:///csv_database.db')

chunksize = 100000
index_offset = 1
for df in pd.read_csv(file, chunksize = chunksize, iterator = True):
      df.index += index_offset
      df.to_sql('table', csv_database, if_exists = 'append')
      index_offset += 1

# %%
df_char_sql1 = pd.read_sql_query("SELECT * FROM 'table'", csv_database)

df_char_sql1 = df_char_sql1 >> drop(['index'])

print(df_char_usual.equals(df_char_sql1))
print(df_char_it.equals(df_char_sql1))
#YAYAYAYAY
# Out:
# True
# True

# %%
df_char_sql1.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75       None         gold    yellow     112BBY
# 2           R2-D2    96.0   32       None  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1    None  Tatooine   Droid
# 2    None     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
#dumping the database and rebuilding without the index_offset, and then checking that dataframes are equal
#this looks the same but it's not
#and tbh I'm too lazy to look for the differences right now
csv_database.dispose()
os.remove('csv_database.db')

csv_database = create_engine('sqlite:///csv_database.db')

chunksize = 10

for df in pd.read_csv(file, chunksize = chunksize, iterator = True):
      df.to_sql('table', csv_database, if_exists = 'append')

df_char_sql2 = pd.read_sql_query("SELECT * FROM 'table'", csv_database)

df_char_sql2 = df_char_sql2 >> drop(['index'])

print(df_char_usual.equals(df_char_sql2))
print(df_char_it.equals(df_char_sql2))
print(df_char_sql1.equals(df_char_sql2))
# Out:
# False
# False
# False

# %%
#looking at the unshared columns
df_char_sql1.merge(df_char_sql2, how = 'outer' ,indicator=False)
# Out:
#                       name  height   mass     hair_color           skin_color  \
# 0           Luke Skywalker   172.0     77          blond                 fair
# 1                    C-3PO   167.0     75           None                 gold
# 2                    R2-D2    96.0     32           None          white, blue
# 3              Darth Vader   202.0    136           none                white
# 4              Leia Organa   150.0     49          brown                light
# 5                Owen Lars   178.0    120    brown, grey                light
# 6       Beru Whitesun lars   165.0     75          brown                light
# 7                    R5-D4    97.0     32           None           white, red
# 8        Biggs Darklighter   183.0     84          black                light
# 9           Obi-Wan Kenobi   182.0     77  auburn, white                 fair
# 10        Anakin Skywalker   188.0     84          blond                 fair
# 11          Wilhuff Tarkin   180.0   None   auburn, grey                 fair
# 12               Chewbacca   228.0    112          brown                 None
# 13                Han Solo   180.0     80          brown                 fair
# 14                  Greedo   173.0     74           None                green
# 15   Jabba Desilijic Tiure   175.0  1,358           None     green-tan, brown
# 16          Wedge Antilles   170.0     77          brown                 fair
# 17        Jek Tono Porkins   180.0    110          brown                 fair
# 18                    Yoda    66.0     17          white                green
# 19               Palpatine   170.0     75           grey                 pale
# 20               Boba Fett   183.0   78.2          black                 fair
# 21                   IG-88   200.0    140           none                metal
# 22                   Bossk   190.0    113           none                green
# 23        Lando Calrissian   177.0     79          black                 dark
# 24                   Lobot   175.0     79           none                light
# 25                  Ackbar   180.0     83           none         brown mottle
# 26              Mon Mothma   150.0   None         auburn                 fair
# 27            Arvel Crynyd     NaN   None          brown                 fair
# 28   Wicket Systri Warrick    88.0     20          brown                brown
# 29               Nien Nunb   160.0     68           none                 grey
# 30            Qui-Gon Jinn   193.0     89          brown                 fair
# 31             Nute Gunray   191.0     90           none        mottled green
# 32           Finis Valorum   170.0   None          blond                 fair
# 33           Jar Jar Binks   196.0     66           none               orange
# 34            Roos Tarpals   224.0     82           none                 grey
# 35              Rugor Nass   206.0   None           none                green
# 36                Ric Olié   183.0   None          brown                 fair
# 37                   Watto   137.0   None          black           blue, grey
# 38                 Sebulba   112.0     40           none            grey, red
# 39           Quarsh Panaka   183.0   None          black                 dark
# 40          Shmi Skywalker   163.0   None          black                 fair
# 41              Darth Maul   175.0     80           none                  red
# 42             Bib Fortuna   180.0   None           none                 pale
# 43             Ayla Secura   178.0     55           none                 blue
# 44                Dud Bolt    94.0     45           none           blue, grey
# 45                 Gasgano   122.0   None           none          white, blue
# 46          Ben Quadinaros   163.0     65           none  grey, green, yellow
# 47              Mace Windu   188.0     84           none                 dark
# 48            Ki-Adi-Mundi   198.0     82          white                 pale
# 49               Kit Fisto   196.0     87           none                green
# 50               Eeth Koth   171.0   None          black                brown
# 51              Adi Gallia   184.0     50           none                 dark
# 52             Saesee Tiin   188.0   None           none                 pale
# 53             Yarael Poof   264.0   None           none                white
# 54                Plo Koon   188.0     80           none               orange
# 55              Mas Amedda   196.0   None           none                 blue
# 56            Gregar Typho   185.0     85          black                 dark
# 57                   Cordé   157.0   None          brown                light
# 58             Cliegg Lars   183.0   None          brown                 fair
# 59       Poggle the Lesser   183.0     80           none                green
# 60         Luminara Unduli   170.0   56.2          black               yellow
# 61           Barriss Offee   166.0     50          black               yellow
# 62                   Dormé   165.0   None          brown                light
# 63                   Dooku   193.0     80          white                 fair
# 64     Bail Prestor Organa   191.0   None          black                  tan
# 65              Jango Fett   183.0     79          black                  tan
# 66              Zam Wesell   168.0     55         blonde  fair, green, yellow
# 67         Dexter Jettster   198.0    102           none                brown
# 68                 Lama Su   229.0     88           none                 grey
# 69                 Taun We   213.0   None           none                 grey
# 70              Jocasta Nu   167.0   None          white                 fair
# 71           Ratts Tyerell    79.0     15           none           grey, blue
# 72                  R4-P17    96.0   None           none          silver, red
# 73              Wat Tambor   193.0     48           none          green, grey
# 74                San Hill   191.0   None           none                 grey
# 75                Shaak Ti   178.0     57           none     red, blue, white
# 76                Grievous   216.0    159           none         brown, white
# 77                 Tarfful   234.0    136          brown                brown
# 78         Raymus Antilles   188.0     79          brown                light
# 79               Sly Moore   178.0     48           none                 pale
# 80              Tion Medon   206.0     80           none                 grey
# 81                    Finn     NaN   None          black                 dark
# 82                     Rey     NaN   None          brown                light
# 83             Poe Dameron     NaN   None          brown                light
# 84                     BB8     NaN   None           none                 none
# 85          Captain Phasma     NaN   None           None                 None
# 86           Padmé Amidala   165.0     45          brown                light
# 87          Luke Skywalker   172.0     77          blond                 fair
# 88                   C-3PO   167.0     75           None                 gold
# 89                   R2-D2    96.0     32           None          white, blue
# 90             Darth Vader   202.0    136           none                white
# 91             Leia Organa   150.0     49          brown                light
# 92               Owen Lars   178.0    120    brown, grey                light
# 93      Beru Whitesun lars   165.0     75          brown                light
# 94                   R5-D4    97.0     32           None           white, red
# 95       Biggs Darklighter   183.0     84          black                light
# 96          Obi-Wan Kenobi   182.0     77  auburn, white                 fair
# 97        Anakin Skywalker   188.0     84          blond                 fair
# 98               Chewbacca   228.0    112          brown                 None
# 99                Han Solo   180.0     80          brown                 fair
# 100                 Greedo   173.0     74           None                green
# 101         Wedge Antilles   170.0     77          brown                 fair
# 102       Jek Tono Porkins   180.0    110          brown                 fair
# 103                   Yoda    66.0     17          white                green
# 104              Palpatine   170.0     75           grey                 pale
# 105              Boba Fett   183.0   78.2          black                 fair
# 106                  IG-88   200.0    140           none                metal
# 107                  Bossk   190.0    113           none                green
# 108       Lando Calrissian   177.0     79          black                 dark
# 109                  Lobot   175.0     79           none                light
# 110                 Ackbar   180.0     83           none         brown mottle
# 111  Wicket Systri Warrick    88.0     20          brown                brown
# 112              Nien Nunb   160.0     68           none                 grey
# 113           Qui-Gon Jinn   193.0     89          brown                 fair
# 114            Nute Gunray   191.0     90           none        mottled green
# 115          Jar Jar Binks   196.0     66           none               orange
# 116           Roos Tarpals   224.0     82           none                 grey
# 117                Sebulba   112.0     40           none            grey, red
# 118             Darth Maul   175.0     80           none                  red
# 119            Ayla Secura   178.0     55           none                 blue
# 120               Dud Bolt    94.0     45           none           blue, grey
# 121         Ben Quadinaros   163.0     65           none  grey, green, yellow
# 122             Mace Windu   188.0     84           none                 dark
# 123           Ki-Adi-Mundi   198.0     82          white                 pale
# 124              Kit Fisto   196.0     87           none                green
# 125             Adi Gallia   184.0     50           none                 dark
# 126               Plo Koon   188.0     80           none               orange
# 127           Gregar Typho   185.0     85          black                 dark
# 128      Poggle the Lesser   183.0     80           none                green
# 129        Luminara Unduli   170.0   56.2          black               yellow
# 130          Barriss Offee   166.0     50          black               yellow
# 131                  Dooku   193.0     80          white                 fair
# 132             Jango Fett   183.0     79          black                  tan
# 133             Zam Wesell   168.0     55         blonde  fair, green, yellow
# 134        Dexter Jettster   198.0    102           none                brown
# 135                Lama Su   229.0     88           none                 grey
# 136          Ratts Tyerell    79.0     15           none           grey, blue
# 137             Wat Tambor   193.0     48           none          green, grey
# 138               Shaak Ti   178.0     57           none     red, blue, white
# 139               Grievous   216.0    159           none         brown, white
# 140                Tarfful   234.0    136          brown                brown
# 141        Raymus Antilles   188.0     79          brown                light
# 142              Sly Moore   178.0     48           none                 pale
# 143             Tion Medon   206.0     80           none                 grey
# 144          Padmé Amidala   165.0     45          brown                light
#
#          eye_color birth_year         gender       homeworld         species
# 0             blue      19BBY           male        Tatooine           Human
# 1           yellow     112BBY           None        Tatooine           Droid
# 2              red      33BBY           None           Naboo           Droid
# 3           yellow    41.9BBY           male        Tatooine           Human
# 4            brown      19BBY         female        Alderaan           Human
# 5             blue      52BBY           male        Tatooine           Human
# 6             blue      47BBY         female        Tatooine           Human
# 7              red       None           None        Tatooine           Droid
# 8            brown      24BBY           male        Tatooine           Human
# 9        blue-gray      57BBY           male         Stewjon           Human
# 10            blue    41.9BBY           male        Tatooine           Human
# 11            blue      64BBY           male          Eriadu           Human
# 12            blue     200BBY           male        Kashyyyk         Wookiee
# 13           brown      29BBY           male        Corellia           Human
# 14           black      44BBY           male           Rodia          Rodian
# 15          orange     600BBY  hermaphrodite       Nal Hutta            Hutt
# 16           hazel      21BBY           male        Corellia           Human
# 17            blue       None           male      Bestine IV           Human
# 18           brown     896BBY           male            None  Yoda's species
# 19          yellow      82BBY           male           Naboo           Human
# 20           brown    31.5BBY           male          Kamino           Human
# 21             red      15BBY           none            None           Droid
# 22             red      53BBY           male       Trandosha      Trandoshan
# 23           brown      31BBY           male         Socorro           Human
# 24            blue      37BBY           male          Bespin           Human
# 25          orange      41BBY           male        Mon Cala    Mon Calamari
# 26            blue      48BBY         female       Chandrila           Human
# 27           brown       None           male            None           Human
# 28           brown       8BBY           male           Endor            Ewok
# 29           black       None           male         Sullust       Sullustan
# 30            blue      92BBY           male            None           Human
# 31             red       None           male  Cato Neimoidia       Neimodian
# 32            blue      91BBY           male       Coruscant           Human
# 33          orange      52BBY           male           Naboo          Gungan
# 34          orange       None           male           Naboo          Gungan
# 35          orange       None           male           Naboo          Gungan
# 36            blue       None           male           Naboo            None
# 37          yellow       None           male        Toydaria       Toydarian
# 38          orange       None           male       Malastare             Dug
# 39           brown      62BBY           male           Naboo            None
# 40           brown      72BBY         female        Tatooine           Human
# 41          yellow      54BBY           male        Dathomir          Zabrak
# 42            pink       None           male          Ryloth         Twi'lek
# 43           hazel      48BBY         female          Ryloth         Twi'lek
# 44          yellow       None           male         Vulpter      Vulptereen
# 45           black       None           male         Troiken           Xexto
# 46          orange       None           male            Tund           Toong
# 47           brown      72BBY           male      Haruun Kal           Human
# 48          yellow      92BBY           male           Cerea          Cerean
# 49           black       None           male     Glee Anselm        Nautolan
# 50           brown       None           male        Iridonia          Zabrak
# 51            blue       None         female       Coruscant      Tholothian
# 52          orange       None           male         Iktotch        Iktotchi
# 53          yellow       None           male         Quermia        Quermian
# 54           black      22BBY           male           Dorin         Kel Dor
# 55            blue       None           male        Champala        Chagrian
# 56           brown       None           male           Naboo           Human
# 57           brown       None         female           Naboo           Human
# 58            blue      82BBY           male        Tatooine           Human
# 59          yellow       None           male        Geonosis       Geonosian
# 60            blue      58BBY         female          Mirial        Mirialan
# 61            blue      40BBY         female          Mirial        Mirialan
# 62           brown       None         female           Naboo           Human
# 63           brown     102BBY           male         Serenno           Human
# 64           brown      67BBY           male        Alderaan           Human
# 65           brown      66BBY           male    Concord Dawn           Human
# 66          yellow       None         female           Zolan        Clawdite
# 67          yellow       None           male            Ojom        Besalisk
# 68           black       None           male          Kamino        Kaminoan
# 69           black       None         female          Kamino        Kaminoan
# 70            blue       None         female       Coruscant           Human
# 71            None       None           male     Aleen Minor          Aleena
# 72       red, blue       None         female            None            None
# 73            None       None           male           Skako         Skakoan
# 74            gold       None           male      Muunilinst            Muun
# 75           black       None         female           Shili         Togruta
# 76   green, yellow       None           male           Kalee         Kaleesh
# 77            blue       None           male        Kashyyyk         Wookiee
# 78           brown       None           male        Alderaan           Human
# 79           white       None         female          Umbara            None
# 80           black       None           male          Utapau          Pau'an
# 81            dark       None           male            None           Human
# 82           hazel       None         female            None           Human
# 83           brown       None           male            None           Human
# 84           black       None           none            None           Droid
# 85            None       None         female            None            None
# 86           brown      46BBY         female           Naboo           Human
# 87            blue      19BBY           male        Tatooine           Human
# 88          yellow     112BBY           None        Tatooine           Droid
# 89             red      33BBY           None           Naboo           Droid
# 90          yellow    41.9BBY           male        Tatooine           Human
# 91           brown      19BBY         female        Alderaan           Human
# 92            blue      52BBY           male        Tatooine           Human
# 93            blue      47BBY         female        Tatooine           Human
# 94             red       None           None        Tatooine           Droid
# 95           brown      24BBY           male        Tatooine           Human
# 96       blue-gray      57BBY           male         Stewjon           Human
# 97            blue    41.9BBY           male        Tatooine           Human
# 98            blue     200BBY           male        Kashyyyk         Wookiee
# 99           brown      29BBY           male        Corellia           Human
# 100          black      44BBY           male           Rodia          Rodian
# 101          hazel      21BBY           male        Corellia           Human
# 102           blue       None           male      Bestine IV           Human
# 103          brown     896BBY           male            None  Yoda's species
# 104         yellow      82BBY           male           Naboo           Human
# 105          brown    31.5BBY           male          Kamino           Human
# 106            red      15BBY           none            None           Droid
# 107            red      53BBY           male       Trandosha      Trandoshan
# 108          brown      31BBY           male         Socorro           Human
# 109           blue      37BBY           male          Bespin           Human
# 110         orange      41BBY           male        Mon Cala    Mon Calamari
# 111          brown       8BBY           male           Endor            Ewok
# 112          black       None           male         Sullust       Sullustan
# 113           blue      92BBY           male            None           Human
# 114            red       None           male  Cato Neimoidia       Neimodian
# 115         orange      52BBY           male           Naboo          Gungan
# 116         orange       None           male           Naboo          Gungan
# 117         orange       None           male       Malastare             Dug
# 118         yellow      54BBY           male        Dathomir          Zabrak
# 119          hazel      48BBY         female          Ryloth         Twi'lek
# 120         yellow       None           male         Vulpter      Vulptereen
# 121         orange       None           male            Tund           Toong
# 122          brown      72BBY           male      Haruun Kal           Human
# 123         yellow      92BBY           male           Cerea          Cerean
# 124          black       None           male     Glee Anselm        Nautolan
# 125           blue       None         female       Coruscant      Tholothian
# 126          black      22BBY           male           Dorin         Kel Dor
# 127          brown       None           male           Naboo           Human
# 128         yellow       None           male        Geonosis       Geonosian
# 129           blue      58BBY         female          Mirial        Mirialan
# 130           blue      40BBY         female          Mirial        Mirialan
# 131          brown     102BBY           male         Serenno           Human
# 132          brown      66BBY           male    Concord Dawn           Human
# 133         yellow       None         female           Zolan        Clawdite
# 134         yellow       None           male            Ojom        Besalisk
# 135          black       None           male          Kamino        Kaminoan
# 136           None       None           male     Aleen Minor          Aleena
# 137           None       None           male           Skako         Skakoan
# 138          black       None         female           Shili         Togruta
# 139  green, yellow       None           male           Kalee         Kaleesh
# 140           blue       None           male        Kashyyyk         Wookiee
# 141          brown       None           male        Alderaan           Human
# 142          white       None         female          Umbara            None
# 143          black       None           male          Utapau          Pau'an
# 144          brown      46BBY         female           Naboo           Human

# %%
df_char_sql1.replace(' ', 'LLLLLLL', regex=True)
#it doesn't seem to be whitespaces
# Out:
#                                  name  height   mass           hair_color  \
# 0                LukeLLLLLLLSkywalker   172.0     77                blond
# 1                               C-3PO   167.0     75                 None
# 2                               R2-D2    96.0     32                 None
# 3                   DarthLLLLLLLVader   202.0    136                 none
# 4                   LeiaLLLLLLLOrgana   150.0     49                brown
# 5                     OwenLLLLLLLLars   178.0    120    brown,LLLLLLLgrey
# 6      BeruLLLLLLLWhitesunLLLLLLLlars   165.0     75                brown
# 7                               R5-D4    97.0     32                 None
# 8             BiggsLLLLLLLDarklighter   183.0     84                black
# 9                Obi-WanLLLLLLLKenobi   182.0     77  auburn,LLLLLLLwhite
# 10             AnakinLLLLLLLSkywalker   188.0     84                blond
# 11               WilhuffLLLLLLLTarkin   180.0   None   auburn,LLLLLLLgrey
# 12                          Chewbacca   228.0    112                brown
# 13                     HanLLLLLLLSolo   180.0     80                brown
# 14                             Greedo   173.0     74                 None
# 15  JabbaLLLLLLLDesilijicLLLLLLLTiure   175.0  1,358                 None
# 16               WedgeLLLLLLLAntilles   170.0     77                brown
# 17       JekLLLLLLLTonoLLLLLLLPorkins   180.0    110                brown
# 18                               Yoda    66.0     17                white
# 19                          Palpatine   170.0     75                 grey
# 20                    BobaLLLLLLLFett   183.0   78.2                black
# 21                              IG-88   200.0    140                 none
# 22                              Bossk   190.0    113                 none
# 23             LandoLLLLLLLCalrissian   177.0     79                black
# 24                              Lobot   175.0     79                 none
# 25                             Ackbar   180.0     83                 none
# 26                   MonLLLLLLLMothma   150.0   None               auburn
# 27                 ArvelLLLLLLLCrynyd     NaN   None                brown
# 28  WicketLLLLLLLSystriLLLLLLLWarrick    88.0     20                brown
# 29                    NienLLLLLLLNunb   160.0     68                 none
# 30                 Qui-GonLLLLLLLJinn   193.0     89                brown
# 31                  NuteLLLLLLLGunray   191.0     90                 none
# 32                FinisLLLLLLLValorum   170.0   None                blond
# 33          JarLLLLLLLJarLLLLLLLBinks   196.0     66                 none
# 34                 RoosLLLLLLLTarpals   224.0     82                 none
# 35                   RugorLLLLLLLNass   206.0   None                 none
# 36                     RicLLLLLLLOlié   183.0   None                brown
# 37                              Watto   137.0   None                black
# 38                            Sebulba   112.0     40                 none
# 39                QuarshLLLLLLLPanaka   183.0   None                black
# 40               ShmiLLLLLLLSkywalker   163.0   None                black
# 41                   DarthLLLLLLLMaul   175.0     80                 none
# 42                  BibLLLLLLLFortuna   180.0   None                 none
# 43                  AylaLLLLLLLSecura   178.0     55                 none
# 44                     DudLLLLLLLBolt    94.0     45                 none
# 45                            Gasgano   122.0   None                 none
# 46               BenLLLLLLLQuadinaros   163.0     65                 none
# 47                   MaceLLLLLLLWindu   188.0     84                 none
# 48                       Ki-Adi-Mundi   198.0     82                white
# 49                    KitLLLLLLLFisto   196.0     87                 none
# 50                    EethLLLLLLLKoth   171.0   None                black
# 51                   AdiLLLLLLLGallia   184.0     50                 none
# 52                  SaeseeLLLLLLLTiin   188.0   None                 none
# 53                  YaraelLLLLLLLPoof   264.0   None                 none
# 54                     PloLLLLLLLKoon   188.0     80                 none
# 55                   MasLLLLLLLAmedda   196.0   None                 none
# 56                 GregarLLLLLLLTypho   185.0     85                black
# 57                              Cordé   157.0   None                brown
# 58                  ClieggLLLLLLLLars   183.0   None                brown
# 59      PoggleLLLLLLLtheLLLLLLLLesser   183.0     80                 none
# 60              LuminaraLLLLLLLUnduli   170.0   56.2                black
# 61                BarrissLLLLLLLOffee   166.0     50                black
# 62                              Dormé   165.0   None                brown
# 63                              Dooku   193.0     80                white
# 64    BailLLLLLLLPrestorLLLLLLLOrgana   191.0   None                black
# 65                   JangoLLLLLLLFett   183.0     79                black
# 66                   ZamLLLLLLLWesell   168.0     55               blonde
# 67              DexterLLLLLLLJettster   198.0    102                 none
# 68                      LamaLLLLLLLSu   229.0     88                 none
# 69                      TaunLLLLLLLWe   213.0   None                 none
# 70                   JocastaLLLLLLLNu   167.0   None                white
# 71                RattsLLLLLLLTyerell    79.0     15                 none
# 72                             R4-P17    96.0   None                 none
# 73                   WatLLLLLLLTambor   193.0     48                 none
# 74                     SanLLLLLLLHill   191.0   None                 none
# 75                     ShaakLLLLLLLTi   178.0     57                 none
# 76                           Grievous   216.0    159                 none
# 77                            Tarfful   234.0    136                brown
# 78              RaymusLLLLLLLAntilles   188.0     79                brown
# 79                    SlyLLLLLLLMoore   178.0     48                 none
# 80                   TionLLLLLLLMedon   206.0     80                 none
# 81                               Finn     NaN   None                black
# 82                                Rey     NaN   None                brown
# 83                  PoeLLLLLLLDameron     NaN   None                brown
# 84                                BB8     NaN   None                 none
# 85               CaptainLLLLLLLPhasma     NaN   None                 None
# 86                PadméLLLLLLLAmidala   165.0     45                brown
#
#                          skin_color            eye_color birth_year  \
# 0                              fair                 blue      19BBY
# 1                              gold               yellow     112BBY
# 2                 white,LLLLLLLblue                  red      33BBY
# 3                             white               yellow    41.9BBY
# 4                             light                brown      19BBY
# 5                             light                 blue      52BBY
# 6                             light                 blue      47BBY
# 7                  white,LLLLLLLred                  red       None
# 8                             light                brown      24BBY
# 9                              fair            blue-gray      57BBY
# 10                             fair                 blue    41.9BBY
# 11                             fair                 blue      64BBY
# 12                             None                 blue     200BBY
# 13                             fair                brown      29BBY
# 14                            green                black      44BBY
# 15           green-tan,LLLLLLLbrown               orange     600BBY
# 16                             fair                hazel      21BBY
# 17                             fair                 blue       None
# 18                            green                brown     896BBY
# 19                             pale               yellow      82BBY
# 20                             fair                brown    31.5BBY
# 21                            metal                  red      15BBY
# 22                            green                  red      53BBY
# 23                             dark                brown      31BBY
# 24                            light                 blue      37BBY
# 25               brownLLLLLLLmottle               orange      41BBY
# 26                             fair                 blue      48BBY
# 27                             fair                brown       None
# 28                            brown                brown       8BBY
# 29                             grey                black       None
# 30                             fair                 blue      92BBY
# 31              mottledLLLLLLLgreen                  red       None
# 32                             fair                 blue      91BBY
# 33                           orange               orange      52BBY
# 34                             grey               orange       None
# 35                            green               orange       None
# 36                             fair                 blue       None
# 37                 blue,LLLLLLLgrey               yellow       None
# 38                  grey,LLLLLLLred               orange       None
# 39                             dark                brown      62BBY
# 40                             fair                brown      72BBY
# 41                              red               yellow      54BBY
# 42                             pale                 pink       None
# 43                             blue                hazel      48BBY
# 44                 blue,LLLLLLLgrey               yellow       None
# 45                white,LLLLLLLblue                black       None
# 46  grey,LLLLLLLgreen,LLLLLLLyellow               orange       None
# 47                             dark                brown      72BBY
# 48                             pale               yellow      92BBY
# 49                            green                black       None
# 50                            brown                brown       None
# 51                             dark                 blue       None
# 52                             pale               orange       None
# 53                            white               yellow       None
# 54                           orange                black      22BBY
# 55                             blue                 blue       None
# 56                             dark                brown       None
# 57                            light                brown       None
# 58                             fair                 blue      82BBY
# 59                            green               yellow       None
# 60                           yellow                 blue      58BBY
# 61                           yellow                 blue      40BBY
# 62                            light                brown       None
# 63                             fair                brown     102BBY
# 64                              tan                brown      67BBY
# 65                              tan                brown      66BBY
# 66  fair,LLLLLLLgreen,LLLLLLLyellow               yellow       None
# 67                            brown               yellow       None
# 68                             grey                black       None
# 69                             grey                black       None
# 70                             fair                 blue       None
# 71                 grey,LLLLLLLblue                 None       None
# 72                silver,LLLLLLLred      red,LLLLLLLblue       None
# 73                green,LLLLLLLgrey                 None       None
# 74                             grey                 gold       None
# 75     red,LLLLLLLblue,LLLLLLLwhite                black       None
# 76               brown,LLLLLLLwhite  green,LLLLLLLyellow       None
# 77                            brown                 blue       None
# 78                            light                brown       None
# 79                             pale                white       None
# 80                             grey                black       None
# 81                             dark                 dark       None
# 82                            light                hazel       None
# 83                            light                brown       None
# 84                             none                black       None
# 85                             None                 None       None
# 86                            light                brown      46BBY
#
#            gender             homeworld               species
# 0            male              Tatooine                 Human
# 1            None              Tatooine                 Droid
# 2            None                 Naboo                 Droid
# 3            male              Tatooine                 Human
# 4          female              Alderaan                 Human
# 5            male              Tatooine                 Human
# 6          female              Tatooine                 Human
# 7            None              Tatooine                 Droid
# 8            male              Tatooine                 Human
# 9            male               Stewjon                 Human
# 10           male              Tatooine                 Human
# 11           male                Eriadu                 Human
# 12           male              Kashyyyk               Wookiee
# 13           male              Corellia                 Human
# 14           male                 Rodia                Rodian
# 15  hermaphrodite       NalLLLLLLLHutta                  Hutt
# 16           male              Corellia                 Human
# 17           male      BestineLLLLLLLIV                 Human
# 18           male                  None  Yoda'sLLLLLLLspecies
# 19           male                 Naboo                 Human
# 20           male                Kamino                 Human
# 21           none                  None                 Droid
# 22           male             Trandosha            Trandoshan
# 23           male               Socorro                 Human
# 24           male                Bespin                 Human
# 25           male        MonLLLLLLLCala    MonLLLLLLLCalamari
# 26         female             Chandrila                 Human
# 27           male                  None                 Human
# 28           male                 Endor                  Ewok
# 29           male               Sullust             Sullustan
# 30           male                  None                 Human
# 31           male  CatoLLLLLLLNeimoidia             Neimodian
# 32           male             Coruscant                 Human
# 33           male                 Naboo                Gungan
# 34           male                 Naboo                Gungan
# 35           male                 Naboo                Gungan
# 36           male                 Naboo                  None
# 37           male              Toydaria             Toydarian
# 38           male             Malastare                   Dug
# 39           male                 Naboo                  None
# 40         female              Tatooine                 Human
# 41           male              Dathomir                Zabrak
# 42           male                Ryloth               Twi'lek
# 43         female                Ryloth               Twi'lek
# 44           male               Vulpter            Vulptereen
# 45           male               Troiken                 Xexto
# 46           male                  Tund                 Toong
# 47           male      HaruunLLLLLLLKal                 Human
# 48           male                 Cerea                Cerean
# 49           male     GleeLLLLLLLAnselm              Nautolan
# 50           male              Iridonia                Zabrak
# 51         female             Coruscant            Tholothian
# 52           male               Iktotch              Iktotchi
# 53           male               Quermia              Quermian
# 54           male                 Dorin         KelLLLLLLLDor
# 55           male              Champala              Chagrian
# 56           male                 Naboo                 Human
# 57         female                 Naboo                 Human
# 58           male              Tatooine                 Human
# 59           male              Geonosis             Geonosian
# 60         female                Mirial              Mirialan
# 61         female                Mirial              Mirialan
# 62         female                 Naboo                 Human
# 63           male               Serenno                 Human
# 64           male              Alderaan                 Human
# 65           male    ConcordLLLLLLLDawn                 Human
# 66         female                 Zolan              Clawdite
# 67           male                  Ojom              Besalisk
# 68           male                Kamino              Kaminoan
# 69         female                Kamino              Kaminoan
# 70         female             Coruscant                 Human
# 71           male     AleenLLLLLLLMinor                Aleena
# 72         female                  None                  None
# 73           male                 Skako               Skakoan
# 74           male            Muunilinst                  Muun
# 75         female                 Shili               Togruta
# 76           male                 Kalee               Kaleesh
# 77           male              Kashyyyk               Wookiee
# 78           male              Alderaan                 Human
# 79         female                Umbara                  None
# 80           male                Utapau                Pau'an
# 81           male                  None                 Human
# 82         female                  None                 Human
# 83           male                  None                 Human
# 84           none                  None                 Droid
# 85         female                  None                  None
# 86         female                 Naboo                 Human

# %%
df_char_sql2.replace(' ', 'LLLLLLL', regex=True)
# Out:
#                                  name  height   mass           hair_color  \
# 0                LukeLLLLLLLSkywalker   172.0     77                blond
# 1                               C-3PO   167.0     75                 None
# 2                               R2-D2    96.0     32                 None
# 3                   DarthLLLLLLLVader   202.0    136                 none
# 4                   LeiaLLLLLLLOrgana   150.0     49                brown
# 5                     OwenLLLLLLLLars   178.0    120    brown,LLLLLLLgrey
# 6      BeruLLLLLLLWhitesunLLLLLLLlars   165.0     75                brown
# 7                               R5-D4    97.0     32                 None
# 8             BiggsLLLLLLLDarklighter   183.0     84                black
# 9                Obi-WanLLLLLLLKenobi   182.0     77  auburn,LLLLLLLwhite
# 10             AnakinLLLLLLLSkywalker   188.0     84                blond
# 11               WilhuffLLLLLLLTarkin   180.0   None   auburn,LLLLLLLgrey
# 12                          Chewbacca   228.0    112                brown
# 13                     HanLLLLLLLSolo   180.0     80                brown
# 14                             Greedo   173.0     74                 None
# 15  JabbaLLLLLLLDesilijicLLLLLLLTiure   175.0  1,358                 None
# 16               WedgeLLLLLLLAntilles   170.0     77                brown
# 17       JekLLLLLLLTonoLLLLLLLPorkins   180.0    110                brown
# 18                               Yoda    66.0     17                white
# 19                          Palpatine   170.0     75                 grey
# 20                    BobaLLLLLLLFett   183.0   78.2                black
# 21                              IG-88   200.0    140                 none
# 22                              Bossk   190.0    113                 none
# 23             LandoLLLLLLLCalrissian   177.0     79                black
# 24                              Lobot   175.0     79                 none
# 25                             Ackbar   180.0     83                 none
# 26                   MonLLLLLLLMothma   150.0   None               auburn
# 27                 ArvelLLLLLLLCrynyd     NaN   None                brown
# 28  WicketLLLLLLLSystriLLLLLLLWarrick    88.0     20                brown
# 29                    NienLLLLLLLNunb   160.0     68                 none
# 30                 Qui-GonLLLLLLLJinn   193.0     89                brown
# 31                  NuteLLLLLLLGunray   191.0     90                 none
# 32                FinisLLLLLLLValorum   170.0   None                blond
# 33          JarLLLLLLLJarLLLLLLLBinks   196.0     66                 none
# 34                 RoosLLLLLLLTarpals   224.0     82                 none
# 35                   RugorLLLLLLLNass   206.0   None                 none
# 36                     RicLLLLLLLOlié   183.0   None                brown
# 37                              Watto   137.0   None                black
# 38                            Sebulba   112.0     40                 none
# 39                QuarshLLLLLLLPanaka   183.0   None                black
# 40               ShmiLLLLLLLSkywalker   163.0   None                black
# 41                   DarthLLLLLLLMaul   175.0     80                 none
# 42                  BibLLLLLLLFortuna   180.0   None                 none
# 43                  AylaLLLLLLLSecura   178.0     55                 none
# 44                     DudLLLLLLLBolt    94.0     45                 none
# 45                            Gasgano   122.0   None                 none
# 46               BenLLLLLLLQuadinaros   163.0     65                 none
# 47                   MaceLLLLLLLWindu   188.0     84                 none
# 48                       Ki-Adi-Mundi   198.0     82                white
# 49                    KitLLLLLLLFisto   196.0     87                 none
# 50                    EethLLLLLLLKoth   171.0   None                black
# 51                   AdiLLLLLLLGallia   184.0     50                 none
# 52                  SaeseeLLLLLLLTiin   188.0   None                 none
# 53                  YaraelLLLLLLLPoof   264.0   None                 none
# 54                     PloLLLLLLLKoon   188.0     80                 none
# 55                   MasLLLLLLLAmedda   196.0   None                 none
# 56                 GregarLLLLLLLTypho   185.0     85                black
# 57                              Cordé   157.0   None                brown
# 58                  ClieggLLLLLLLLars   183.0   None                brown
# 59      PoggleLLLLLLLtheLLLLLLLLesser   183.0     80                 none
# 60              LuminaraLLLLLLLUnduli   170.0   56.2                black
# 61                BarrissLLLLLLLOffee   166.0     50                black
# 62                              Dormé   165.0   None                brown
# 63                              Dooku   193.0     80                white
# 64    BailLLLLLLLPrestorLLLLLLLOrgana   191.0   None                black
# 65                   JangoLLLLLLLFett   183.0     79                black
# 66                   ZamLLLLLLLWesell   168.0     55               blonde
# 67              DexterLLLLLLLJettster   198.0    102                 none
# 68                      LamaLLLLLLLSu   229.0     88                 none
# 69                      TaunLLLLLLLWe   213.0   None                 none
# 70                   JocastaLLLLLLLNu   167.0   None                white
# 71                RattsLLLLLLLTyerell    79.0     15                 none
# 72                             R4-P17    96.0   None                 none
# 73                   WatLLLLLLLTambor   193.0     48                 none
# 74                     SanLLLLLLLHill   191.0   None                 none
# 75                     ShaakLLLLLLLTi   178.0     57                 none
# 76                           Grievous   216.0    159                 none
# 77                            Tarfful   234.0    136                brown
# 78              RaymusLLLLLLLAntilles   188.0     79                brown
# 79                    SlyLLLLLLLMoore   178.0     48                 none
# 80                   TionLLLLLLLMedon   206.0     80                 none
# 81                               Finn     NaN   None                black
# 82                                Rey     NaN   None                brown
# 83                  PoeLLLLLLLDameron     NaN   None                brown
# 84                                BB8     NaN   None                 none
# 85               CaptainLLLLLLLPhasma     NaN   None                 None
# 86                PadméLLLLLLLAmidala   165.0     45                brown
#
#                          skin_color            eye_color birth_year  \
# 0                              fair                 blue      19BBY
# 1                              gold               yellow     112BBY
# 2                 white,LLLLLLLblue                  red      33BBY
# 3                             white               yellow    41.9BBY
# 4                             light                brown      19BBY
# 5                             light                 blue      52BBY
# 6                             light                 blue      47BBY
# 7                  white,LLLLLLLred                  red       None
# 8                             light                brown      24BBY
# 9                              fair            blue-gray      57BBY
# 10                             fair                 blue    41.9BBY
# 11                             fair                 blue      64BBY
# 12                             None                 blue     200BBY
# 13                             fair                brown      29BBY
# 14                            green                black      44BBY
# 15           green-tan,LLLLLLLbrown               orange     600BBY
# 16                             fair                hazel      21BBY
# 17                             fair                 blue       None
# 18                            green                brown     896BBY
# 19                             pale               yellow      82BBY
# 20                             fair                brown    31.5BBY
# 21                            metal                  red      15BBY
# 22                            green                  red      53BBY
# 23                             dark                brown      31BBY
# 24                            light                 blue      37BBY
# 25               brownLLLLLLLmottle               orange      41BBY
# 26                             fair                 blue      48BBY
# 27                             fair                brown       None
# 28                            brown                brown       8BBY
# 29                             grey                black       None
# 30                             fair                 blue      92BBY
# 31              mottledLLLLLLLgreen                  red       None
# 32                             fair                 blue      91BBY
# 33                           orange               orange      52BBY
# 34                             grey               orange       None
# 35                            green               orange       None
# 36                             fair                 blue       None
# 37                 blue,LLLLLLLgrey               yellow       None
# 38                  grey,LLLLLLLred               orange       None
# 39                             dark                brown      62BBY
# 40                             fair                brown      72BBY
# 41                              red               yellow      54BBY
# 42                             pale                 pink       None
# 43                             blue                hazel      48BBY
# 44                 blue,LLLLLLLgrey               yellow       None
# 45                white,LLLLLLLblue                black       None
# 46  grey,LLLLLLLgreen,LLLLLLLyellow               orange       None
# 47                             dark                brown      72BBY
# 48                             pale               yellow      92BBY
# 49                            green                black       None
# 50                            brown                brown       None
# 51                             dark                 blue       None
# 52                             pale               orange       None
# 53                            white               yellow       None
# 54                           orange                black      22BBY
# 55                             blue                 blue       None
# 56                             dark                brown       None
# 57                            light                brown       None
# 58                             fair                 blue      82BBY
# 59                            green               yellow       None
# 60                           yellow                 blue      58BBY
# 61                           yellow                 blue      40BBY
# 62                            light                brown       None
# 63                             fair                brown     102BBY
# 64                              tan                brown      67BBY
# 65                              tan                brown      66BBY
# 66  fair,LLLLLLLgreen,LLLLLLLyellow               yellow       None
# 67                            brown               yellow       None
# 68                             grey                black       None
# 69                             grey                black       None
# 70                             fair                 blue       None
# 71                 grey,LLLLLLLblue                 None       None
# 72                silver,LLLLLLLred      red,LLLLLLLblue       None
# 73                green,LLLLLLLgrey                 None       None
# 74                             grey                 gold       None
# 75     red,LLLLLLLblue,LLLLLLLwhite                black       None
# 76               brown,LLLLLLLwhite  green,LLLLLLLyellow       None
# 77                            brown                 blue       None
# 78                            light                brown       None
# 79                             pale                white       None
# 80                             grey                black       None
# 81                             dark                 dark       None
# 82                            light                hazel       None
# 83                            light                brown       None
# 84                             none                black       None
# 85                             None                 None       None
# 86                            light                brown      46BBY
#
#            gender             homeworld               species
# 0            male              Tatooine                 Human
# 1            None              Tatooine                 Droid
# 2            None                 Naboo                 Droid
# 3            male              Tatooine                 Human
# 4          female              Alderaan                 Human
# 5            male              Tatooine                 Human
# 6          female              Tatooine                 Human
# 7            None              Tatooine                 Droid
# 8            male              Tatooine                 Human
# 9            male               Stewjon                 Human
# 10           male              Tatooine                 Human
# 11           male                Eriadu                 Human
# 12           male              Kashyyyk               Wookiee
# 13           male              Corellia                 Human
# 14           male                 Rodia                Rodian
# 15  hermaphrodite       NalLLLLLLLHutta                  Hutt
# 16           male              Corellia                 Human
# 17           male      BestineLLLLLLLIV                 Human
# 18           male                  None  Yoda'sLLLLLLLspecies
# 19           male                 Naboo                 Human
# 20           male                Kamino                 Human
# 21           none                  None                 Droid
# 22           male             Trandosha            Trandoshan
# 23           male               Socorro                 Human
# 24           male                Bespin                 Human
# 25           male        MonLLLLLLLCala    MonLLLLLLLCalamari
# 26         female             Chandrila                 Human
# 27           male                  None                 Human
# 28           male                 Endor                  Ewok
# 29           male               Sullust             Sullustan
# 30           male                  None                 Human
# 31           male  CatoLLLLLLLNeimoidia             Neimodian
# 32           male             Coruscant                 Human
# 33           male                 Naboo                Gungan
# 34           male                 Naboo                Gungan
# 35           male                 Naboo                Gungan
# 36           male                 Naboo                  None
# 37           male              Toydaria             Toydarian
# 38           male             Malastare                   Dug
# 39           male                 Naboo                  None
# 40         female              Tatooine                 Human
# 41           male              Dathomir                Zabrak
# 42           male                Ryloth               Twi'lek
# 43         female                Ryloth               Twi'lek
# 44           male               Vulpter            Vulptereen
# 45           male               Troiken                 Xexto
# 46           male                  Tund                 Toong
# 47           male      HaruunLLLLLLLKal                 Human
# 48           male                 Cerea                Cerean
# 49           male     GleeLLLLLLLAnselm              Nautolan
# 50           male              Iridonia                Zabrak
# 51         female             Coruscant            Tholothian
# 52           male               Iktotch              Iktotchi
# 53           male               Quermia              Quermian
# 54           male                 Dorin         KelLLLLLLLDor
# 55           male              Champala              Chagrian
# 56           male                 Naboo                 Human
# 57         female                 Naboo                 Human
# 58           male              Tatooine                 Human
# 59           male              Geonosis             Geonosian
# 60         female                Mirial              Mirialan
# 61         female                Mirial              Mirialan
# 62         female                 Naboo                 Human
# 63           male               Serenno                 Human
# 64           male              Alderaan                 Human
# 65           male    ConcordLLLLLLLDawn                 Human
# 66         female                 Zolan              Clawdite
# 67           male                  Ojom              Besalisk
# 68           male                Kamino              Kaminoan
# 69         female                Kamino              Kaminoan
# 70         female             Coruscant                 Human
# 71           male     AleenLLLLLLLMinor                Aleena
# 72         female                  None                  None
# 73           male                 Skako               Skakoan
# 74           male            Muunilinst                  Muun
# 75         female                 Shili               Togruta
# 76           male                 Kalee               Kaleesh
# 77           male              Kashyyyk               Wookiee
# 78           male              Alderaan                 Human
# 79         female                Umbara                  None
# 80           male                Utapau                Pau'an
# 81           male                  None                 Human
# 82         female                  None                 Human
# 83           male                  None                 Human
# 84           none                  None                 Droid
# 85         female                  None                  None
# 86         female                 Naboo                 Human

# %%
print(df_char_sql2.shape)
print(df_char_sql1.shape)
# Out:
# (87, 10)
# (87, 10)

# %%
print((df_char_sql2.replace(' ', 'LLLLLLL', regex=True)).equals((df_char_sql1.replace(' ', 'LLLLLLL', regex=True))))
# Out:
# False
